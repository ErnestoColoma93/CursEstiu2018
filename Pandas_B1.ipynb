# %%
# %matplotlib inline

# %% [markdown]
# # Basics B1
#
# <img src="files/pandas_logo.png">
#
#
# **Pandas** es la librería por excelencia para el análisis de datos. Su nombre proviene de “panel data” (término econométrico). Inspirada en las funcionalidades de R, pero con el potencial de Python.
#
# **Pandas** incluye 'todas’ las funcionalidades para el análisis de datos: carga, filtrado, tratamiento, sintetización, agrupamiento, almacenamiento y visualización. Además se integra con el resto de librerías de calculo númerico como Numpy, Matplotlib, scikit-learn, …  y despliegues: HPC, Cloud, etc.
#
#
#
# En resumen, es como un “una hoja de calculo" -por ejemplo el excel- pero con más potencial!!!
#
# <a target="_blank" href="http://pandas.pydata.org/">http://pandas.pydata.org/</a> (See: Library Highlights)

# %% [markdown]
# # Contenido
#
# - B1 Introducción a la estructura DataFrame. Características, Carga y Acceso
# - B2 Creación y Almacenamiento
# - B3 Agrupaciones
# - B4 Uniendo datos y gestionando datos perdidos
# - B5 Visualización
# - B6 Series Temporales

# %% [markdown]
# ## Cómo trabajaremos
#
# - Explicación e Interacción
# - Jupyter Notebooks > Slideshow
# - En Campus Extens : Notebooks (Jupyter) & ficheros de datos
# - Notebooks peculiares:

# %%
print ("Hello World")
# Out:
# Hello World

# %%
#Instrucción que debéis escribir vosotros
print ("Hola Mundo" )#**
# Out:
# Hola Mundo

# %% [markdown]
# **Atención**: Riesgo de sincronización!

# %% [markdown]
# # Introducción a Pandas
# ## La estructura por excelencia es el DataFrame
# Un **dataframe** es un objeto de dos dimensiones de objetos. También puede verse como una hoja de cálculo o como una tabla de un modelo entidad-relación, o como una colección de una base mongodb.
#
# <a target="_blank" href="http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.html"> Dataframe.html</a> (See library)
#
# **Capacidad**: *Soltura en el uso de la documentación de las librerías de Python*

# %% [markdown]
# # Primeros pasos con Pandas
# Vamos a aprender Pandas através de una serie de proyectos y ejemplos.<br/>
# En este primera fase vamos a cargar datos de un fichero CSV, son ficheros donde los atributos/valores están separados por una coma
#
# ### Ejemplo de un fichero CSV
# Nombre,Apellidos,Altura,Sexo,Nacimiento,Cof,Categoria<br/>
# Will,Smith,1.43,"M",10/10/1920,0.19,laboral<br/>
# Jon,Snow,1.98,"M",10/1/1970,0.98,laboral<br/>
# Laia,Ramirez,1.87,"F",09/10/1987,0.76,cap6<br/>
# Luzy,Raim,1.67,"F",23/07/1979,0.56,cap6<br/>
# Fein,Mang,1.78,"M",12/03/1937,0.27,cap6<br/>
# Victor,Colom,1.78,"M",22/09/1957,0.97,cap8<br/>
#
#
# http://www.exploredata.net/Downloads/WHO-Data-Set

# %%
#Cargamos un fichero **
import pandas as pd
df = pd.read_csv("data/WHO.csv")

# %%
df
# Out:
#                       Country  CountryID  Continent  \
# 0                 Afghanistan          1          1
# 1                     Albania          2          2
# 2                     Algeria          3          3
# 3                     Andorra          4          2
# 4                      Angola          5          3
# 5         Antigua and Barbuda          6          4
# 6                   Argentina          7          5
# 7                     Armenia          8          2
# 8                   Australia          9          6
# 9                     Austria         10          2
# 10                 Azerbaijan         11          2
# 11                    Bahamas         12          4
# 12                    Bahrain         13          1
# 13                 Bangladesh         14          7
# 14                   Barbados         15          4
# 15                    Belarus         16          2
# 16                    Belgium         17          2
# ...

# %%
df.shape # Ver las dimensiones **
# Out:
# (202, 358)

# %%
df.columns #**
# Out:
# Index(['Country', 'CountryID', 'Continent', 'Adolescent fertility rate (%)',
#        'Adult literacy rate (%)',
#        'Gross national income per capita (PPP international $)',
#        'Net primary school enrolment ratio female (%)',
#        'Net primary school enrolment ratio male (%)',
#        'Population (in thousands) total', 'Population annual growth rate (%)',
#        ...
#        'Total_CO2_emissions', 'Total_income', 'Total_reserves',
#        'Trade_balance_goods_and_services', 'Under_five_mortality_from_CME',
#        'Under_five_mortality_from_IHME', 'Under_five_mortality_rate',
#        'Urban_population', 'Urban_population_growth',
#        'Urban_population_pct_of_total'],
#       dtype='object', length=358)

# %%
for col in df.columns: #**
    print (col)
# Out:
# Country
# CountryID
# Continent
# Adolescent fertility rate (%)
# Adult literacy rate (%)
# Gross national income per capita (PPP international $)
# Net primary school enrolment ratio female (%)
# Net primary school enrolment ratio male (%)
# Population (in thousands) total
# Population annual growth rate (%)
# Population in urban areas (%)
# Population living below the poverty line (% living on &lt; US$1 per day)
# Population median age (years)
# Population proportion over 60 (%)
# Population proportion under 15 (%)
# Registration coverage of births (%)
# Total fertility rate (per woman)
# Antenatal care coverage - at least four visits (%)
# Antiretroviral therapy coverage among HIV-infected pregt women for PMTCT (%)
# Antiretroviral therapy coverage among people with advanced HIV infections (%)
# Births attended by skilled health personnel (%)
# Births by caesarean section (%)
# Children aged 6-59 months who received vitamin A supplementation (%)
# ...

# %%
for i , col in enumerate (df.columns): #**
    print ( i , col)
# Out:
# 0 Country
# 1 CountryID
# 2 Continent
# 3 Adolescent fertility rate (%)
# 4 Adult literacy rate (%)
# 5 Gross national income per capita (PPP international $)
# 6 Net primary school enrolment ratio female (%)
# 7 Net primary school enrolment ratio male (%)
# 8 Population (in thousands) total
# 9 Population annual growth rate (%)
# 10 Population in urban areas (%)
# 11 Population living below the poverty line (% living on &lt; US$1 per day)
# 12 Population median age (years)
# 13 Population proportion over 60 (%)
# 14 Population proportion under 15 (%)
# 15 Registration coverage of births (%)
# 16 Total fertility rate (per woman)
# 17 Antenatal care coverage - at least four visits (%)
# 18 Antiretroviral therapy coverage among HIV-infected pregt women for PMTCT (%)
# 19 Antiretroviral therapy coverage among people with advanced HIV infections (%)
# 20 Births attended by skilled health personnel (%)
# 21 Births by caesarean section (%)
# ...

# %%
df.columns[0] #**
# Out:
# 'Country'

# %%
df.columns[10] #**
# Out:
# 'Population in urban areas (%)'

# %% [markdown]
# ## Podemos ver con una serie de funciones características del dataframe
#  #**

# %%
df.describe()
# Out:
#         CountryID   Continent  Adolescent fertility rate (%)  \
# count  202.000000  202.000000                     177.000000
# mean   101.500000    3.579208                      59.457627
# std     58.456537    1.808263                      49.105286
# min      1.000000    1.000000                       0.000000
# 25%     51.250000    2.000000                      19.000000
# 50%    101.500000    3.000000                      46.000000
# 75%    151.750000    5.000000                      91.000000
# max    202.000000    7.000000                     199.000000
#
#        Adult literacy rate (%)  \
# count               131.000000
# mean                 78.871756
# std                  20.415760
# min                  23.600000
# 25%                  68.400000
# 50%                  86.500000
# 75%                  95.300000
# max                  99.800000
#
#        Gross national income per capita (PPP international $)  \
# count                                         178.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202 entries, 0 to 201
# Columns: 358 entries, Country to Urban_population_pct_of_total
# dtypes: float64(355), int64(2), object(1)
# memory usage: 565.0+ KB

# %%
df.index
# Out:
# RangeIndex(start=0, stop=202, step=1)

# %%
df.head()
# Out:
#        Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 0  Afghanistan          1          1                          151.0
# 1      Albania          2          2                           27.0
# 2      Algeria          3          3                            6.0
# 3      Andorra          4          2                            NaN
# 4       Angola          5          3                          146.0
#
#    Adult literacy rate (%)  \
# 0                     28.0
# 1                     98.7
# 2                     69.9
# 3                      NaN
# 4                     67.4
#
#    Gross national income per capita (PPP international $)  \
# 0                                                NaN
# 1                                             6000.0
# 2                                             5940.0
# 3                                                NaN
# 4                                             3890.0
#
#    Net primary school enrolment ratio female (%)  \
# ...

# %%
df.tail()
# Out:
#                 Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 197             Vietnam        198          6                           25.0
# 198  West Bank and Gaza        199          1                            NaN
# 199               Yemen        200          1                           83.0
# 200              Zambia        201          3                          161.0
# 201            Zimbabwe        202          3                          101.0
#
#      Adult literacy rate (%)  \
# 197                     90.3
# 198                      NaN
# 199                     54.1
# 200                     68.0
# 201                     89.5
#
#      Gross national income per capita (PPP international $)  \
# 197                                             2310.0
# 198                                                NaN
# 199                                             2090.0
# 200                                             1140.0
# ...

# %%
df.tail(3)
# Out:
#       Country  CountryID  Continent  Adolescent fertility rate (%)  \
# 199     Yemen        200          1                           83.0
# 200    Zambia        201          3                          161.0
# 201  Zimbabwe        202          3                          101.0
#
#      Adult literacy rate (%)  \
# 199                     54.1
# 200                     68.0
# 201                     89.5
#
#      Gross national income per capita (PPP international $)  \
# 199                                             2090.0
# 200                                             1140.0
# 201                                                NaN
#
#      Net primary school enrolment ratio female (%)  \
# 199                                           65.0
# 200                                           94.0
# 201                                           88.0
#
#      Net primary school enrolment ratio male (%)  \
# 199                                         85.0
# ...

# %% [markdown]
# # Selección de información: por columnas o por filas
# #**

# %%
#df[0] #Un dataframe no es un array.... no podemos acceder via []

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# # Accediendo a una columna mediante el Indice de Columnas

# %%
df["Country"] #**
# Out:
# 0                   Afghanistan
# 1                       Albania
# 2                       Algeria
# 3                       Andorra
# 4                        Angola
# 5           Antigua and Barbuda
# 6                     Argentina
# 7                       Armenia
# 8                     Australia
# 9                       Austria
# 10                   Azerbaijan
# 11                      Bahamas
# 12                      Bahrain
# 13                   Bangladesh
# 14                     Barbados
# 15                      Belarus
# 16                      Belgium
# 17                       Belize
# 18                        Benin
# 19                      Bermuda
# 20                       Bhutan
# 21                      Bolivia
# 22       Bosnia and Herzegovina
# 23                     Botswana
# 24                       Brazil
# 25            Brunei Darussalam
# 26                     Bulgaria
# 27                 Burkina Faso
# 28                      Burundi
# ...

# %%
df.Country #**
# Out:
# 0                   Afghanistan
# 1                       Albania
# 2                       Algeria
# 3                       Andorra
# 4                        Angola
# 5           Antigua and Barbuda
# 6                     Argentina
# 7                       Armenia
# 8                     Australia
# 9                       Austria
# 10                   Azerbaijan
# 11                      Bahamas
# 12                      Bahrain
# 13                   Bangladesh
# 14                     Barbados
# 15                      Belarus
# 16                      Belgium
# 17                       Belize
# 18                        Benin
# 19                      Bermuda
# 20                       Bhutan
# 21                      Bolivia
# 22       Bosnia and Herzegovina
# 23                     Botswana
# 24                       Brazil
# 25            Brunei Darussalam
# 26                     Bulgaria
# 27                 Burkina Faso
# 28                      Burundi
# ...

# %%
type(df.Country) #¿Qué es una columna? #**
# Out:
# pandas.core.series.Series

# %%
print( df.columns[3])
print (df[df.columns[3]])
print ("Valor medio de %s = %f " %(df.columns[3],df[df.columns[3]].mean()))
# Out:
# Adolescent fertility rate (%)
# 0      151.0
# 1       27.0
# 2        6.0
# 3        NaN
# 4      146.0
# 5        NaN
# 6       62.0
# 7       30.0
# 8       16.0
# 9       14.0
# 10      31.0
# 11      46.0
# 12      14.0
# 13     135.0
# 14      51.0
# 15      22.0
# 16       5.0
# 17      90.0
# 18     108.0
# 19       NaN
# 20      62.0
# 21      97.0
# 22      25.0
# 23      51.0
# 24      71.0
# 25      31.0
# 26      40.0
# 27     131.0
# 28      30.0
# 29      52.0
#        ...
# 172     73.0
# 173      7.0
# 174      5.0
# 175     58.0
# 176      NaN
# 177     57.0
# 178    139.0
# 179     70.0
# 180     49.0
# 181     89.0
# 182     17.0
# 183     35.0
# 184      8.0
# 185     51.0
# 186     29.0
# 187      NaN
# 188    159.0
# 189     29.0
# 190     37.0
# 191     27.0
# 192     43.0
# 193     64.0
# 194     40.0
# 195     92.0
# 196     81.0
# 197     25.0
# 198      NaN
# 199     83.0
# 200    161.0
# 201    101.0
# ...

# %% [markdown]
# ## Sintetización de información
# Sobre las series se puede sintetizar información

# %%
fertilidad = df[df.columns[3]] ## aplicamos la columna al dataframe para seleccionar
print ("Minimo %f " %fertilidad.min())
print ("Max %f " %fertilidad.max())
print ("Mean %f " %fertilidad.mean())
print ("Descripción de la serie:\n%s " %fertilidad.describe())
# Out:
# Minimo 0.000000
# Max 199.000000
# Mean 59.457627
# Descripción de la serie:
# count    177.000000
# mean      59.457627
# std       49.105286
# min        0.000000
# 25%       19.000000
# 50%       46.000000
# 75%       91.000000
# max      199.000000
# Name: Adolescent fertility rate (%), dtype: float64

# %% [markdown]
# ## Funciones de sintetización
# <img src="files/sintetizacion.png">

# %% [markdown]
# # Y por fin... Visualización
# Veremos como visualizar series y dataframes en próximas secciones

# %%
fertilidad.plot()

# %% [markdown]
# ### Alerta: En las columnas/series de un dataframe podemos aplicar lo aprendido con Numpy!!

# %%
print ("(PANDAS) Suma de fertilidades: %f " %fertilidad.sum())
import numpy as np
print ("(NUMPY) Suma de fertilidades: %f " %np.sum(fertilidad))
# Out:
# (PANDAS) Suma de fertilidades: 10524.000000
# (NUMPY) Suma de fertilidades: 10524.000000

# %% [markdown]
# ## La selección puede ser muy eficaz para encontrar elementos que cumplan ciertos criterios
# Dentro de cada 'selección' se pueden aplicar condiciones. Veamos un ejemplo...
# #**

# %% [markdown]
# #### ¿Qué pais tiene la mayor emisión de CO2 ?

# %%
co2= df["Total_CO2_emissions"]
print (co2.max())
row = df[df["Total_CO2_emissions"]==co2.max() ]  # Esto es una condición dentro de la selección
# Out:
# 5776431.5

# %%
type(row)
# Out:
# pandas.core.frame.DataFrame

# %%
print (row["Country"]) #Obtenemos un objeto concreto (una celda de la Serie Contries que cumple con la condición)
# Out:
# 192    United States of America
# Name: Country, dtype: object

# %%
print (row["Country"].values) #Los valores del objeto son un array
# Out:
# ['United States of America']

# %%
print (row["Country"].values[0])
# Out:
# United States of America

# %% [markdown]
# ### Cual es el segundo pais más contaminante??

# %%
co2= df["Total_CO2_emissions"]

# %% [markdown]
# # Accediendo, mediante FILAS
# #**

# %%
df[0]

# %%
df.index

# %%
for i in pd.RangeIndex(0,20,step=4):
    print i

# %%
for i in np.arange(0,20,4):
    print i

# %% [markdown]
# ### OK, pero ¿cómo podemos acceder mediante un INDEX a una FILA?
# #**

# %%
df.loc[4]

# %%
df.loc[4:5] #**

# %% [markdown]
# ### Si entendemos el concepto de acceso a un array...

# %%
array =[1,2,3,4,5,6,7,9,0]
print array[0:2] #**
print array[3:] #**
print array[:3] #**

# %%
df.loc[200:]  #**

# %% [markdown]
# ## Haciendo lo mismo con arrays...

# %%
array =[[1,2],[2,3],[4,5],[6,7],[9,0]]
print (type(array)) #**
nparray = np.array(array) #**
print (type(nparray)) #**
print (nparray.shape) #**

# %%
print (nparray[:])

# %%
print (nparray[:2]) #**

# %%
print (nparray[:,1]) #**

# %%
print(nparray[:,0])

# %%
print (nparray[0:3,1]) #**

# %%
df.loc[0:1] # LO HACEMOS CON LOC!! #**

# %%
df.loc[0:1,["Continent"]]

# %%
df.loc[0:1,["Continent","Total_CO2_emissions"]]

# %%
df.ix[0] #Está es otra manera más rudimentaria de acceder, vía un Integer/Número

# %%
df.ix[0:4] #**

# %%
df.ix[0][0] #**

# %%
df.ix[0][0:4]

# %%
df.ix[0][0:4].values

# %%
df.ix[0][0:4].values[0] #**

# %% [markdown]
# # EJERCICIOS

# %% [markdown]
# ### 1) ¿Cuál es el país con mayor crecimiento urbano (“Urban_population_growth”)?

# %%
grow = df['Urban_population_growth']
row3 = df[df["Urban_population_growth"]==grow.max()] 
print (row3['Country'].values[0])
# Out:
# Rwanda

# %% [markdown]
# ### 2A) ¿Cuál es el país con menor crecimiento urbano?

# %%
row4 = df[df["Urban_population_growth"]==grow.min()]
print(row4['Country'].values[0])
# Out:
# Georgia

# %% [markdown]
# ### 2B) ¿Qué paises tienen un crecimiento urbano por encima 3.0?

# %%
row5 = df[df["Urban_population_growth"]>3.0]
print(row5['Country'])
# Out:
# 0                           Afghanistan
# 4                                Angola
# 13                           Bangladesh
# 17                               Belize
# 18                                Benin
# 20                               Bhutan
# 27                         Burkina Faso
# 28                              Burundi
# 29                             Cambodia
# 30                             Cameroon
# 32                           Cape Verde
# 34                                 Chad
# 38                              Comoros
# 39                     Congo, Dem. Rep.
# 56                              Eritrea
# 58                             Ethiopia
# 64                               Gambia
# 67                                Ghana
# 70                            Guatemala
# 71                               Guinea
# 74                                Haiti
# 80                            Indonesia
# 90                                Kenya
# ...

# %% [markdown]
# ### 3) ¿DESCRIBE  las características de la fila: “Spain”?
# Busca el identificador de la fila de SPAIN mediante una condición de igualdad con la columas de nombres de paises

# %%
rowS= df[df["Country"]== 'Spain']
rowS.describe()
# Out:
#        CountryID  Continent  Adolescent fertility rate (%)  \
# count        1.0        1.0                            1.0
# mean       169.0        2.0                           10.0
# std          NaN        NaN                            NaN
# min        169.0        2.0                           10.0
# 25%        169.0        2.0                           10.0
# 50%        169.0        2.0                           10.0
# 75%        169.0        2.0                           10.0
# max        169.0        2.0                           10.0
#
#        Adult literacy rate (%)  \
# count                      1.0
# mean                      97.2
# std                        NaN
# min                       97.2
# 25%                       97.2
# 50%                       97.2
# 75%                       97.2
# max                       97.2
#
#        Gross national income per capita (PPP international $)  \
# count                                                1.0
# ...

# %% [markdown]
# ### 4) ¿El continente donde está situado Spain es el mismo de UnitedStates?
# Utiliza una condición para que obtengamos el resultado de: True or False

# %%
c1=df[df['Country']=='United States of America']
c2 = df[df['Country']=='Spain']
c1['Continent'].values[0]== c2['Continent'].values[0]
# Out:
# False

# %% [markdown]
# ### 5) ¿Cuáles son los cinco paises más contaminantes?
# Esta es mi pista para una solución elegante: http://pandas.pydata.org/pandas-docs/version/0.19.2/generated/pandas.DataFrame.sort.html

# %%
result = df.sort_values('Total_CO2_emissions', ascending=0)
result.head(5)
# Out:
#                       Country  CountryID  Continent  \
# 192  United States of America        193          4
# 36                      China         37          7
# 149                    Russia        150          2
# 79                      India         80          7
# 87                      Japan         88          6
#
#      Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 192                           43.0                      NaN
# 36                             3.0                     90.9
# 149                           28.0                     99.4
# 79                            97.0                     61.0
# 87                             6.0                      NaN
#
#      Gross national income per capita (PPP international $)  \
# 192                                            44070.0
# 36                                              4660.0
# 149                                            12740.0
# 79                                              2460.0
# ...

# %% [markdown]
# ### 6) Observando algunas muestras del fichero puedes establecer la relación entre el identificador del continente y su nombre?
# Es decir, sabemos que Spain está en el continente Europeo y el código del continente es el 2. <br/> El objetivo es un diccionario con esta estructura:

# %%
codigoContinentes = {1:"Asia",2:"Europa"} #Al menos hay 7!
print (codigoContinentes)
# Out:
# {1: 'Asia', 2: 'Europa'}

# %%
con1=df[df['Country']=='United States of America']
con1['Continent']
con2=df[df['Country']=='Australia']
con2['Continent']
con3=df[df['Country']=='India']
con3['Continent']
con4=df[df['Country']=='Argentina']
con4['Continent']
con5=df[df['Country']=='Rwanda']
con5['Continent']
# Out:
# 150    3
# Name: Continent, dtype: int64

# %%
codigoContinentes[int(con1['Continent'])]  = 'America del norte'
codigoContinentes[int(con2['Continent'])]  = 'Oceania'
codigoContinentes[int(con3['Continent'])]  = 'Asia menor'
codigoContinentes[int(con4['Continent'])]  = 'America del sur'
codigoContinentes[int(con5['Continent'])]  = 'Africa'

print (codigoContinentes)
# Out:
# {1: 'Asia', 2: 'Europa', 4: 'America del norte', 6: 'Oceania', 7: 'Asia menor', 5: 'America del sur', 3: 'Africa'}

# %% [markdown]
# ### 7) Una vez identificado el nombre de los continentes, ¿puedes cambiar la columna de identificadores de continentes por sus respectivos nombres?
# Esta es es mi pista para una solución elegante: http://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.map.html

# %%
#ll = df['Continent'].map(codigoContinentes)
df.replace({'Continent': codigoContinentes },  inplace = True) ## Para mi una solucion mas sencilla y elegante 
df[0:10]
# Out:
#                Country  CountryID          Continent  \
# 0          Afghanistan          1               Asia
# 1              Albania          2             Europa
# 2              Algeria          3             Africa
# 3              Andorra          4             Europa
# 4               Angola          5             Africa
# 5  Antigua and Barbuda          6  America del norte
# 6            Argentina          7    America del sur
# 7              Armenia          8             Europa
# 8            Australia          9            Oceania
# 9              Austria         10             Europa
#
#    Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 0                          151.0                     28.0
# 1                           27.0                     98.7
# 2                            6.0                     69.9
# 3                            NaN                      NaN
# 4                          146.0                     67.4
# ...

# %% [markdown]
# ### 8) Puedes crear un nuevo dataframe con aquellos paises que sean de Europa.

# %%
df2 = df #Con una simple asignación ya creas una dataframe 
type(df2)
df2.head(3)
# Out:
#        Country  CountryID Continent  Adolescent fertility rate (%)  \
# 0  Afghanistan          1      Asia                          151.0
# 1      Albania          2    Europa                           27.0
# 2      Algeria          3    Africa                            6.0
#
#    Adult literacy rate (%)  \
# 0                     28.0
# 1                     98.7
# 2                     69.9
#
#    Gross national income per capita (PPP international $)  \
# 0                                                NaN
# 1                                             6000.0
# 2                                             5940.0
#
#    Net primary school enrolment ratio female (%)  \
# 0                                            NaN
# 1                                           93.0
# 2                                           94.0
#
#    Net primary school enrolment ratio male (%)  \
# 0                                          NaN
# 1                                         94.0
# ...

# %%
df2 = df[df['Continent'] == "Europa"]
df2
# Out:
#                     Country  CountryID Continent  \
# 1                   Albania          2    Europa
# 3                   Andorra          4    Europa
# 7                   Armenia          8    Europa
# 9                   Austria         10    Europa
# 10               Azerbaijan         11    Europa
# 15                  Belarus         16    Europa
# 16                  Belgium         17    Europa
# 22   Bosnia and Herzegovina         23    Europa
# 26                 Bulgaria         27    Europa
# 44                  Croatia         45    Europa
# 46                   Cyprus         47    Europa
# 47           Czech Republic         48    Europa
# 48                  Denmark         49    Europa
# 57                  Estonia         58    Europa
# 60                  Finland         61    Europa
# 61                   France         62    Europa
# 65                  Georgia         66    Europa
# 66                  Germany         67    Europa
# ...

# %% [markdown]
# ### 9) ¿Cuáles son los paises más contaminantes de Europa?
# Propuesta A: usa el dataframe inicial

# %%
most_cont2=df.sort_values('Total_CO2_emissions',ascending=0)
most_cont2.head(10)
# Out:
#                       Country  CountryID          Continent  \
# 192  United States of America        193  America del norte
# 36                      China         37         Asia menor
# 149                    Russia        150             Europa
# 79                      India         80         Asia menor
# 87                      Japan         88            Oceania
# 66                    Germany         67             Europa
# 191            United Kingdom        192             Europa
# 31                     Canada         32  America del norte
# 93                Korea, Rep.         94            Oceania
# 85                      Italy         86             Europa
#
#      Adolescent fertility rate (%)  Adult literacy rate (%)  \
# 192                           43.0                      NaN
# 36                             3.0                     90.9
# 149                           28.0                     99.4
# 79                            97.0                     61.0
# ...

# %% [markdown]
# Propuesta B: usa el dataframe de la actividad 8

# %%
most_cont=df2.sort_values('Total_CO2_emissions',ascending=0)
most_cont.head(10)
# Out:
#             Country  CountryID Continent  Adolescent fertility rate (%)  \
# 149          Russia        150    Europa                           28.0
# 66          Germany         67    Europa                           11.0
# 191  United Kingdom        192    Europa                           27.0
# 85            Italy         86    Europa                            7.0
# 61           France         62    Europa                            8.0
# 168           Spain        169    Europa                           10.0
# 189         Ukraine        190    Europa                           29.0
# 144          Poland        145    Europa                           14.0
# 185          Turkey        186    Europa                           51.0
# 89       Kazakhstan         90    Europa                           26.0
#
#      Adult literacy rate (%)  \
# 149                     99.4
# 66                       NaN
# 191                      NaN
# 85                      98.4
# ...

# %% [markdown]
# ### 10) ¿Cuál es el continente con mayor número de paises?
# La solución elegante la veremos en el siguiente punto teórico.

# %%
canti = df.groupby(['Continent']).size()
canti
# Out:
# Continent
# Africa               48
# America del norte     7
# America del sur      31
# Asia                 21
# Asia menor            9
# Europa               51
# Oceania              35
# dtype: int64

# %% [markdown]
# ### Conclusión
# #### Competencias adquiridas en el B1:
# <ul>
#   <li>Carga de ficheros CSV</li>
#   <li>Selección de filas y columnas de un dataframe</li>
#   <li>Aplicación de criterios en la selección</li>
# </ul>
